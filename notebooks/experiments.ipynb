# %% [markdown]
# # Experiments Notebook
#
# This notebook is intended for experiments and quick local demos related to the Retrieval-Augmented Generation (RAG) system.
#
# ## TODO
# - Load example documents from `data/example.txt`.
# - Implement chunking of the loaded documents using the `Chunker` class from `src/chunking/chunker.py`.
# - Embed the chunks using the `Embedder` class from `src/embedding/embedder.py`.
# - Store the vectors in the vector database using the `VectorDB` class from `src/vectordb/db.py`.
# - Retrieve top-k similar vectors using the `Retriever` class from `src/retrieval/retriever.py`.
# - Generate answers using the `RagLLM` class from `src/generation/rag_llm.py`.
# - Document findings and results from experiments.
#
# ## Setup
# Make sure to install the required packages listed in `requirements.txt` before running the experiments.

# %%
# Import necessary modules
from src.chunking.chunker import Chunker
from src.embedding.embedder import Embedder
from src.vectordb.db import VectorDB
from src.retrieval.retriever import Retriever
from src.generation.rag_llm import RagLLM

# Initialize components
chunker = Chunker()
embedder = Embedder()
vector_db = VectorDB()
retriever = Retriever()
rag_llm = RagLLM()

# TODO: Load documents, chunk, embed, store, and retrieve
